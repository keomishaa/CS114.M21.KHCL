# %%
import math

n_testcase = int(input())

for i in range(n_testcase):
    n = int(input())
    ar = list(map(int, input().split(' ')[:n]))
    sum = 0
    for j in ar:
        sum = sum + j
    print(math.ceil(sum/n))
