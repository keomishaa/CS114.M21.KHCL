# %%
n = int(input())
m = n
lst = []

def split(n, lst):
    while n > 0:
        lst.append(n%10)
        n = int(n/10)

split(n,lst)

luythua = 0
for i in lst:
    luythua = luythua + 1

sum = 0
for i in lst:
    sum = sum + i**luythua

if sum == m:
    print(True)
else:
    print(False)
