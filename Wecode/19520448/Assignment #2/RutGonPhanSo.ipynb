# %%
import math
n = int(input())

for i in range(n):
    a, b = map(int, input().split())
    c = math.gcd(a,b)
    if a%b==0:
        print(a//b)
    else:
        a = a // c
        b = b // c
        print(a,b)
