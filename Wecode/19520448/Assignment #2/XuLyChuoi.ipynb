# %%
Bob_str = input()
Bob_str = Bob_str.lower()
check_str = "AOYEUIaoyeui"
for i in Bob_str:
    for j in check_str:
        if i == j:
            Bob_str = Bob_str.replace(i,"")
for i in Bob_str:
    print("."+i, end="")
